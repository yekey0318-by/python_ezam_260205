# %%
class Employee:
    def work(self):
        print("직원이 일을 합니다.")

class Manager(Employee):
    def work(self):
        super().work()  # 부모 클래스의 work 메서드 호출
        print("매니저가 팀을 관리합니다.")

manager = Manager()
manager.work()
# Out:
# 직원이 일을 합니다.
# 매니저가 팀을 관리합니다.
